# %%
import pandas as pd

# %%
df = pd.read_csv('insurance.csv')

# %%
# df.head()
df.sample(5)
# Out:
#     age  weight  height  ...     city      occupation insurance_premium_category
# 26   33    79.0    1.61  ...   Jaipur      freelancer                     Medium
# 95   36    52.8    1.57  ...   Indore  business_owner                        Low
# 92   37    62.7    1.85  ...  Lucknow  government_job                        Low
# 53   41   101.3    1.85  ...    Delhi  government_job                     Medium
# 90   59    54.0    1.60  ...   Mumbai  business_owner                        Low
#
# [5 rows x 8 columns]

# %% [markdown]
# Get a copy of original data

# %%
df_feat = df.copy()

# %% [markdown]
# - Feature 1 : BMI

# %%
df_feat['bmi'] = df_feat["weight"]/(df_feat["height"]**2)

# %% [markdown]
# - Feature 2 : Age group

# %%
def age_group(age):
    if age < 25:
        return "young"
    elif age < 45:
        return "adult"
    elif age < 60:
        return "midle_aged"
    return "senior"

# %%
df_feat["age_group"] = df_feat["age"].apply(age_group)

# %% [markdown]
# - Feature 3 : Lifestyle risk

# %%
def lifestyle_risk(row):
    if row["smoker"] and row["bmi"] > 30:
        return "high"
    elif row["smoker"] and row["bmi"] > 27:
        return "medium"
    return "low"

# %%
df_feat["lifestyle_risk"] = df_feat.apply(lifestyle_risk,axis=1)

# %% [markdown]
# *Cities breakdown*

# %%
tier_1_cities = ["Mumbai", "Delhi", "Bangalore", "Chennai", "Kolkata", "Hyderabad", "Pune"]
tier_2_cities = [
    "Jaipur", "Chandigarh", "Indore", "Lucknow", "Patna", "Ranchi", "Visakhapatnam", "Coimbatore",
    "Bhopal", "Nagpur", "Vadodara", "Surat", "Rajkot", "Jodhpur", "Raipur", "Amritsar", "Varanasi",
    "Agra", "Dehradun", "Mysore", "Jabalpur", "Guwahati", "Thiruvananthapuram", "Ludhiana", "Nashik",
    "Allahabad", "Udaipur", "Aurangabad", "Hubli", "Belgaum", "Salem", "Vijayawada", "Tiruchirappalli",
    "Bhavnagar", "Gwalior", "Dhanbad", "Bareilly", "Aligarh", "Gaya", "Kozhikode", "Warangal",
    "Kolhapur", "Bilaspur", "Jalandhar", "Noida", "Guntur", "Asansol", "Siliguri"
]

# %% [markdown]
# - Feature 4 : City Tier

# %%
def city_tier(city):
    if city in tier_1_cities:
        return 1
    elif city in tier_2_cities:
        return 2
    return 3

# %%
df_feat["city_tier"] = df_feat["city"].apply(city_tier)

# %%
# df_feat.drop(columns=['age', 'weight', 'height', 'smoker', 'city'])
df_feat.drop(columns=['age', 'weight', 'height', 'smoker', 'city'],inplace=True)

# %%
df_feat.sample(10)
# Out:
#     income_lpa      occupation  ... city_tier   age_group
# 31   11.770000     private_job  ...         2       adult
# 15    2.990000         retired  ...         1      senior
# 10   32.780000  business_owner  ...         1       adult
# 98   28.300000  business_owner  ...         1       adult
# 37    8.090000      freelancer  ...         2       adult
# 44   50.000000     private_job  ...         2  midle_aged
# 57    1.360000         retired  ...         2      senior
# 12   17.580000      freelancer  ...         2       adult
# 43    1.560000         retired  ...         1      senior
# 94   10.542289  government_job  ...         1  midle_aged
#
# [10 rows x 7 columns]

# %% [markdown]
# *select features and target*

# %%
x = df_feat[["bmi", "age_group", "lifestyle_risk", "city_tier", "income_lpa", "occupation"]]
y = df_feat["insurance_premium_category"]

# %%
x
# Out:
#           bmi   age_group lifestyle_risk  city_tier  income_lpa      occupation
# 0   49.227482      senior            low          2     2.92000         retired
# 1   30.189017       adult            low          1    34.28000      freelancer
# 2   21.118382       adult            low          2    36.64000      freelancer
# 3   45.535900       young           high          1     3.34000         student
# 4   24.296875      senior            low          2     3.94000         retired
# ..        ...         ...            ...        ...         ...             ...
# 95  21.420747       adult            low          2    19.64000  business_owner
# 96  47.984483       adult            low          1    34.01000     private_job
# 97  18.765432  midle_aged            low          1    44.86000      freelancer
# 98  30.521676       adult            low          1    28.30000  business_owner
# 99  27.688778       adult         medium          1    28.16664  government_job
#
# [100 rows x 6 columns]

# %%
y
# Out:
# 0       High
# 1        Low
# 2        Low
# 3     Medium
# 4       High
#        ...
# 95       Low
# 96       Low
# 97       Low
# 98       Low
# 99       Low
# Name: insurance_premium_category, Length: 100, dtype: object

# %% [markdown]
# **Define categorical and numerical features**

# %%
categorical_features = ["age_group","lifestyle_risk","occupation","city_tier"]
numerical_features = ["bmi","income_lpa"]

# %% [markdown]
# *Create column transformation for OneHotEncoder*

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
preprocessor = ColumnTransformer(
    transformers = [
        ("cat",OneHotEncoder(),categorical_features),
        ("num","passthrough",numerical_features)
    ]
)

# %% [markdown]
# *Create a pipeline with preprocessing and random forest classifier*

# %%
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
pipeline = Pipeline(steps=[
    ("preprocessor",preprocessor),
    ("classifier",RandomForestClassifier(random_state=42))
])

# %% [markdown]
# *Split and train the model*

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=1)
pipeline.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('cat', OneHotEncoder(),
#                                                   ['age_group',
#                                                    'lifestyle_risk',
#                                                    'occupation', 'city_tier']),
#                                                  ('num', 'passthrough',
#                                                   ['bmi', 'income_lpa'])])),
#                 ('classifier', RandomForestClassifier(random_state=42))])

# %% [markdown]
# *Predict and evaluate*

# %%
from sklearn.metrics import accuracy_score
y_pred = pipeline.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.75

# %%
x_test.sample(5)
# Out:
#           bmi   age_group lifestyle_risk  city_tier  income_lpa      occupation
# 78  27.932798  midle_aged         medium          2   14.740000      freelancer
# 69  21.942857  midle_aged            low          2    6.034487  government_job
# 52  47.344720       young            low          2    2.960000         student
# 44  30.078125  midle_aged           high          2   50.000000     private_job
# 56  42.414152       young           high          1    2.860000         student

# %% [markdown]
# **Save the Trained pipeline using pickle**

# %%
import pickle
pickle_model_path = "model.pkl"
with open(pickle_model_path,"wb") as f:
    pickle.dump(pipeline,f)
